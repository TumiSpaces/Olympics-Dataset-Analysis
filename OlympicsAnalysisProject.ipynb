# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#load data 

import pandas as pd

athletes = pd.read_csv('/Users/mashelenkwinika/Desktop/athlete_events.csv')
regions = pd.read_csv('/Users/mashelenkwinika/Desktop/noc_regions.csv')

# %%
athletes.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
regions.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
#Join the dataframe

athletes_df = athletes.merge(regions, how = 'left', on ='NOC') 
athletes_df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       region notes
# 0       Basketball Men's Basketball   NaN        China   NaN
# ...

# %%
print(athletes_df.shape)
# Out:
# (271116, 17)

# %%
#Column names consistent

athletes_df.rename(columns={'region':'Region', 'notes':'Notes'}, inplace =True)

# %%
athletes_df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       Region Notes
# 0       Basketball Men's Basketball   NaN        China   NaN
# ...

# %%
athletes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 271116 entries, 0 to 271115
# Data columns (total 17 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
#  15  Region  270746 non-null  object
#  16  Notes   5039 non-null    object
# dtypes: float64(3), int64(2), object(12)
# memory usage: 37.2+ MB

# %%
athletes_df.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
#check null values 

nan_values = athletes_df.isna()
nan_columns = nan_values.any()
nan_columns
# Out:
# ID        False
# Name      False
# Sex       False
# Age        True
# Height     True
# Weight     True
# Team      False
# NOC       False
# Games     False
# Year      False
# Season    False
# City      False
# Sport     False
# Event     False
# Medal      True
# Region     True
# Notes      True
# dtype: bool

# %%
#total number of nan values

athletes_df.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# Region       370
# Notes     266077
# dtype: int64

# %%
#print columns with containing nan values or missong values in the form of a list

nan_columns = athletes_df.columns[athletes_df.isnull().any()].tolist()
print(nan_columns)
# Out:
# ['Age', 'Height', 'Weight', 'Medal', 'Region', 'Notes']

# %%
#American details

athletes_df.query('Team == "Jamaica"').head(5)
# Out:
#         ID                         Name Sex   Age  Height  Weight     Team  \
# 1539   854              Derrick Adamson   M  26.0   177.0    72.0  Jamaica
# 1540   854              Derrick Adamson   M  30.0   177.0    72.0  Jamaica
# 4048  2334  Samantha Albert (Majendie-)   F  37.0   165.0    59.0  Jamaica
# 4049  2334  Samantha Albert (Majendie-)   F  41.0   165.0    59.0  Jamaica
# 4285  2451               Peter Aldridge   M  19.0   173.0    69.0  Jamaica
#
#       NOC        Games  Year  Season         City          Sport  \
# 1539  JAM  1984 Summer  1984  Summer  Los Angeles      Athletics
# 1540  JAM  1988 Summer  1988  Summer        Seoul      Athletics
# 4048  JAM  2008 Summer  2008  Summer      Beijing  Equestrianism
# 4049  JAM  2012 Summer  2012  Summer       London  Equestrianism
# 4285  JAM  1980 Summer  1980  Summer       Moskva        Cycling
#
#                                                 Event Medal   Region Notes
# ...

# %%
# Japan details

athletes_df.query('Team == "Japan"').head(5)
# Out:
#       ID         Name Sex   Age  Height  Weight   Team  NOC        Games  \
# 625  362  Isao Ko Abe   M  24.0   177.0    75.0  Japan  JPN  1936 Summer
# 629  363   Kazumi Abe   M  28.0   178.0    67.0  Japan  JPN  1976 Winter
# 630  364    Kazuo Abe   M  25.0   166.0    69.0  Japan  JPN  1960 Summer
# 631  365    Kinya Abe   M  23.0   168.0    68.0  Japan  JPN  1992 Summer
# 632  366  Kiyoshi Abe   M  25.0   167.0    62.0  Japan  JPN  1972 Summer
#
#      Year  Season       City      Sport  \
# 625  1936  Summer     Berlin  Athletics
# 629  1976  Winter  Innsbruck  Bobsleigh
# 630  1960  Summer       Roma  Wrestling
# 631  1992  Summer  Barcelona    Fencing
# 632  1972  Summer     Munich  Wrestling
#
#                                         Event Medal Region Notes
# 625              Athletics Men's Hammer Throw   NaN  Japan   NaN
# 629                      Bobsleigh Men's Four   NaN  Japan   NaN
# 630    Wrestling Men's Lightweight, Freestyle   NaN  Japan   NaN
# ...

# %%
#Top countries participating since 1896

top_10_countries = athletes_df.Team.value_counts().sort_values(ascending=False).head(10)
print(top_10_countries)
# Out:
# United States    17847
# France           11988
# Great Britain    11404
# Italy            10260
# Germany           9326
# Canada            9279
# Japan             8289
# Sweden            8052
# Australia         7513
# Hungary           6547
# Name: Team, dtype: int64

# %%
#Plot for the top 10 countries
plt.figure(figsize=(12,6))
plt.title('Overall Participation by Country')
sns.barplot(x=top_10_countries.index, y=top_10_countries, palette='Set2');

# %%
#Age Distribution of the athletes: Histogram 

plt.figure(figsize=(12, 6))
plt.title("Age distribution of Athletes")
plt.xlabel('Age')
plt.ylabel('Number of participants')
plt.hist(athletes_df.Age, bins = np.arange(10,80,2), color = 'orange', edgecolor = 'white');

# %%
#Winter Olympics sports

winter_sports =athletes_df[athletes_df.Season == 'Winter'].Sport.unique()
winter_sports
# Out:
# array(['Speed Skating', 'Cross Country Skiing', 'Ice Hockey', 'Biathlon',
#        'Alpine Skiing', 'Luge', 'Bobsleigh', 'Figure Skating',
#        'Nordic Combined', 'Freestyle Skiing', 'Ski Jumping', 'Curling',
#        'Snowboarding', 'Short Track Speed Skating', 'Skeleton',
#        'Military Ski Patrol', 'Alpinism'], dtype=object)

# %%
#Summer olympics sports

summer_sports =athletes_df[athletes_df.Season == 'Summer'].Sport.unique()
summer_sports
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Athletics',
#        'Swimming', 'Badminton', 'Sailing', 'Gymnastics',
#        'Art Competitions', 'Handball', 'Weightlifting', 'Wrestling',
#        'Water Polo', 'Hockey', 'Rowing', 'Fencing', 'Equestrianism',
#        'Shooting', 'Boxing', 'Taekwondo', 'Cycling', 'Diving', 'Canoeing',
#        'Tennis', 'Modern Pentathlon', 'Golf', 'Softball', 'Archery',
#        'Volleyball', 'Synchronized Swimming', 'Table Tennis', 'Baseball',
#        'Rhythmic Gymnastics', 'Rugby Sevens', 'Trampolining',
#        'Beach Volleyball', 'Triathlon', 'Rugby', 'Lacrosse', 'Polo',
#        'Cricket', 'Ice Hockey', 'Racquets', 'Motorboating', 'Croquet',
#        'Figure Skating', 'Jeu De Paume', 'Roque', 'Basque Pelota',
#        'Alpinism', 'Aeronautics'], dtype=object)

# %%
#Male and Female participants

gender_counts = athletes_df.Sex.value_counts()
gender_counts
# Out:
# M    196594
# F     74522
# Name: Sex, dtype: int64

# %%
#pie plot for male and female  athletes

plt.figure(figsize= (12, 6))
plt.title('Gender Distribution')
plt.pie(gender_counts, labels=gender_counts.index, autopct = '%1.1f%%', startangle=150, shadow=True);

# %%
#Total medals 

athletes_df.Medal.value_counts()
# Out:
# Gold      13372
# Bronze    13295
# Silver    13116
# Name: Medal, dtype: int64

# %%
#Total number of female athletes in each olympics 

female_participants = athletes_df[(athletes_df.Sex =='F') & (athletes_df.Season == 'Summer')][['Sex', 'Year']] 
female_participants = female_participants.groupby('Year').count().reset_index()
female_participants.tail()
# Out:
#     Year   Sex
# 23  2000  5431
# 24  2004  5546
# 25  2008  5816
# 26  2012  5815
# 27  2016  6223

# %%
import pandas as pd

athletes = pd.read_csv('/Users/mashelenkwinika/Desktop/athlete_events.csv')
regions = pd.read_csv('/Users/mashelenkwinika/Desktop/noc_regions.csv')

# %%
athletes_df = athletes.merge(regions, how = 'left', on ='NOC') 
athletes_df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       region notes
# 0       Basketball Men's Basketball   NaN        China   NaN
# ...

# %%
athletes_df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       Region Notes
# 0       Basketball Men's Basketball   NaN        China   NaN
# ...

# %%
athletes_df.rename(columns={'region':'Region', 'notes':'Notes'}, inplace =True)

# %%
womenOlympics = athletes_df[(athletes_df.Sex == 'F') & (athletes_df.Season == 'Summer')]

# %%
#create a countplot using Seaborn

import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="darkgrid") 
plt.figure(figsize=(20, 10))
sns.countplot(x='Year', data=womenOlympics, palette="Spectral")
plt.title('Women Participation')
plt.show()

# %%
#create a line graph to show the trend

part = womenOlympics.groupby('Year')['Sex'].value_counts()
plt.figure(figsize=(20, 10))
part.loc[:,'F'].plot()
plt.title('Plot of Female Athletes over Time')
# Out:
# Text(0.5, 1.0, 'Plot of Female Athletes over Time')

# %%
#Gold medals athelets

goldMedals = athletes_df[(athletes_df.Medal == 'Gold')]
goldMedals.head()
# Out:
#     ID                     Name Sex   Age  Height  Weight            Team  \
# 3    4     Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 42  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 44  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 48  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 60  20       Kjetil Andr Aamodt   M  20.0   176.0    85.0          Norway
#
#     NOC        Games  Year  Season         City          Sport  \
# 3   DEN  1900 Summer  1900  Summer        Paris     Tug-Of-War
# 42  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 44  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 48  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 60  NOR  1992 Winter  1992  Winter  Albertville  Alpine Skiing
#
#                                Event Medal   Region Notes
# 3        Tug-Of-War Men's Tug-Of-War  Gold  Denmark   NaN
# ...

# %%
# State only the value that are diffrent from nan

import numpy as np

goldMedals = goldMedals[np.isfinite(goldMedals['Age'])]

# %%
#Gold Beyond 60

goldMedals['ID'][goldMedals['Age'] > 60].count()
# Out:
# 6

# %%
#check sport for which this 6 medals come

sporting_event = goldMedals['Sport'][goldMedals['Age']>60]
print(sporting_event)
# Out:
# 104003    Art Competitions
# 105199               Roque
# 190952             Archery
# 226374             Archery
# 233390            Shooting
# 261102             Archery
# Name: Sport, dtype: object

# %%
#total Gold medals for each country
goldMedals.Region.value_counts().reset_index(name='Medal').head(5)
# Out:
#      index  Medal
# 0      USA   2627
# 1   Russia   1599
# 2  Germany   1293
# 3       UK    657
# 4    Italy    567

# %%
totalGoldMedals = goldMedals.Region.value_counts().reset_index(name='Medal').head(6)

# %%
g = sns.catplot(x="index", y="Medal", data=totalGoldMedals, height=5, kind="bar", palette="rocket")
g.despine(left=True)
g.set(xlabel="Top 5 countries", ylabel="Number of medals")
plt.title('Gold Medals per Country')
# Out:
# Text(0.5, 1.0, 'Gold Medals per Country')

# %%
#Rion Olympics
max_year = athletes_df.Year.max()
print(max_year)

team_names = athletes_df[(athletes_df.Year == max_year)& (athletes_df.Medal == 'Gold')].Team

team_names.value_counts().head(10)
# Out:
# 2016
# United States    137
# Great Britain     64
# Russia            50
# Germany           47
# China             44
# Brazil            34
# Australia         23
# Argentina         21
# France            20
# Japan             17
# Name: Team, dtype: int64

# %%
sns.barplot(x=team_names.value_counts().head(20), y=team_names.value_counts().head(20).index)
plt.ylabel(None);
plt.xlabel('Countrywise medla for the year 2016')
# Out:
# Text(0.5, 0, 'Countrywise medla for the year 2016')

# %%
not_null_medals = athletes_df[(athletes_df['Height'].notnull()) &(athletes_df['Weight'].notnull())]

# %%
not_null_metals = athletes_df.dropna(subset=['Height', 'Weight'])

# %%
axis = sns.scatterplot(x="Height", y="Weight", data=not_null_medals, hue="Sex")
